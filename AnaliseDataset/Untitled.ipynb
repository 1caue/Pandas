# %% [markdown]
# # Análise de dados utilizando o dataframe do campeonato brasileiro

# %%
import pandas as pd
from IPython.display import display

data1 = pd.read_csv(r'C:\Users\CAUÊ\Documents\Pandas\AnaliseDataset\campeonato-brasileiro-cartoes.csv')
data2 = pd.read_csv(r'C:\Users\CAUÊ\Documents\Pandas\AnaliseDataset\campeonato-brasileiro-gols.csv')

df1 = pd.DataFrame(data1)
df2 = pd.DataFrame(data2)

main_df = df1.set_index('partida_id').join(df2.set_index('clube'), rsuffix='_tab2')

display(main_df)
# Out:
#             rodata          clube    cartao                      atleta  \
# partida_id
# 4607             1    Figueirense   Amarelo      Paulo Roberto da Silva
# 4607             1    Figueirense   Amarelo               Thiago Heleno
# 4608             1  Internacional   Amarelo         Andrés D'Alessandro
# 4608             1        Vitoria   Amarelo  Marcelo Machado dos Santos
# 4608             1        Vitoria   Amarelo                      Mansur
# ...            ...            ...       ...                         ...
# 8405            38          Vasco   Amarelo                 Gabriel Pec
# 8405            38          Vasco   Amarelo                    Paulinho
# 8405            38          Vasco   Amarelo                  Gary Medel
# 8405            38     Bragantino   Amarelo               Eduardo Sasha
# 8405            38     Bragantino  Vermelho                  Léo Realpe
#
#             num_camisa     posicao minuto  partida_id  rodata_tab2  \
# partida_id
# ...

# %%
data1.query('(cartao == "Amarelo" or cartao == "Vermelho") and clube == "Bragantino"').head(20) # Fazendo procura
# Out:
#        partida_id  rodata       clube    cartao                  atleta  \
# 11225        6889       1  Bragantino   Amarelo          Ricardo Ryller
# 11237        6898       2  Bragantino   Amarelo          Ricardo Ryller
# 11239        6898       2  Bragantino   Amarelo          Fabrício Bruno
# 11240        6898       2  Bragantino   Amarelo           Matheus Jesus
# 11299        6910       3  Bragantino   Amarelo          Ricardo Ryller
# 11326        6917       4  Bragantino   Amarelo            Edimar Fraga
# 11327        6917       4  Bragantino   Amarelo           Matheus Jesus
# 11331        6917       4  Bragantino   Amarelo       Lucas Evangelista
# 11332        6917       4  Bragantino   Amarelo            Luis Phelipe
# 11333        6917       4  Bragantino   Amarelo  Artur Victor Guimarães
# 11407        6932       5  Bragantino   Amarelo               Léo Ortiz
# 11408        6932       5  Bragantino  Vermelho          Fabrício Bruno
# ...

# %%
display(df1) # Primeiro DataFrame
# Out:
#        partida_id  rodata          clube    cartao  \
# 0            4607       1    Figueirense   Amarelo
# 1            4607       1    Figueirense   Amarelo
# 2            4608       1  Internacional   Amarelo
# 3            4608       1        Vitoria   Amarelo
# 4            4608       1        Vitoria   Amarelo
# ...           ...     ...            ...       ...
# 18852        8405      38          Vasco   Amarelo
# 18853        8405      38          Vasco   Amarelo
# 18854        8405      38          Vasco   Amarelo
# 18855        8405      38     Bragantino   Amarelo
# 18856        8405      38     Bragantino  Vermelho
#
#                            atleta  num_camisa     posicao minuto
# 0          Paulo Roberto da Silva        28.0         NaN     66
# 1                   Thiago Heleno         4.0    Zagueiro     44
# 2             Andrés D'Alessandro        10.0  Meio-campo     72
# 3      Marcelo Machado dos Santos        29.0         NaN     86
# ...

# %%
display(df2) # Segundo DataFrame
# Out:
#       partida_id  rodata          clube                             atleta  \
# 0           4607       1     Fluminense            Nirley da Silva Fonseca
# 1           4607       1     Fluminense                               Fred
# 2           4607       1     Fluminense                       Rafael Sóbis
# 3           4608       1  Internacional                   Charles Aránguiz
# 4           4612       1       Cruzeiro             Nílton Ferreira Júnior
# ...          ...     ...            ...                                ...
# 8927        8403      38         Santos  Messias Rodrigues da Silva Júnior
# 8928        8404      38      Sao Paulo             Luciano da Rocha Neves
# 8929        8405      38          Vasco      Sergio Antonio De Luiz Junior
# 8930        8405      38     Bragantino                          Léo Ortiz
# 8931        8405      38          Vasco                           Paulinho
#
#      minuto tipo_de_gol
# 0        59  Gol Contra
# ...

# %%
main_df.shape
# Out:
# (18857, 12)

# %%
# Unindo os databases para melhor visualização
merge_databases = pd.concat([data1, data2], keys=['Jogo 1', 'Jogo 2'], axis=1) 
display(merge_databases)
# Out:
#           Jogo 1                                                              \
#       partida_id rodata          clube    cartao                      atleta
# 0           4607      1    Figueirense   Amarelo      Paulo Roberto da Silva
# 1           4607      1    Figueirense   Amarelo               Thiago Heleno
# 2           4608      1  Internacional   Amarelo         Andrés D'Alessandro
# 3           4608      1        Vitoria   Amarelo  Marcelo Machado dos Santos
# 4           4608      1        Vitoria   Amarelo                      Mansur
# ...          ...    ...            ...       ...                         ...
# 18852       8405     38          Vasco   Amarelo                 Gabriel Pec
# 18853       8405     38          Vasco   Amarelo                    Paulinho
# 18854       8405     38          Vasco   Amarelo                  Gary Medel
# 18855       8405     38     Bragantino   Amarelo               Eduardo Sasha
# ...

# %%
# Unindo os DataFrames e atribuindo a uma variável
merge = pd.merge(data1, data2, on='clube')
display(merge)
# Out:
#          partida_id_x  rodata_x        clube    cartao  \
# 0                4607         1  Figueirense   Amarelo
# 1                4607         1  Figueirense   Amarelo
# 2                4607         1  Figueirense   Amarelo
# 3                4607         1  Figueirense   Amarelo
# 4                4607         1  Figueirense   Amarelo
# ...               ...       ...          ...       ...
# 6563174          8405        38   Bragantino  Vermelho
# 6563175          8405        38   Bragantino  Vermelho
# 6563176          8405        38   Bragantino  Vermelho
# 6563177          8405        38   Bragantino  Vermelho
# 6563178          8405        38   Bragantino  Vermelho
#
#                        atleta_x  num_camisa   posicao minuto_x  partida_id_y  \
# 0        Paulo Roberto da Silva        28.0       NaN       66          4650
# 1        Paulo Roberto da Silva        28.0       NaN       66          4685
# ...

# %%
merge.shape
# Out:
# (6563179, 13)

# %% [markdown]
# # Criando DF para atribuição de valores utilizando o Matplotlib

# %%
jogadores = pd.DataFrame({'Jogador ': ['Pedro', 'João', 'Vitor', 'Ryan'], 
                          'Gols': [3, 2, 6, 1], 
                          'Cartão':['Amarelo', 'Amarelo', 'Vermelho', 'Nenhum']})
display(jogadores)
# Out:
#   Jogador   Gols    Cartão
# 0    Pedro     3   Amarelo
# 1     João     2   Amarelo
# 2    Vitor     6  Vermelho
# 3     Ryan     1    Nenhum

# %%
time = pd.DataFrame({'Time': ['Flamengo', 'Flamengo', 'Fluminense', 'Vasco'], 
                     'Gols na Liga': [4, 5, 8, 1],
                     'Partidas': [4, 5, 5, 4]})

display(time)
# Out:
#          Time  Gols na Liga  Partidas
# 0    Flamengo             4         4
# 1    Flamengo             5         5
# 2  Fluminense             8         5
# 3       Vasco             1         4

# %%
tot = jogadores.join(time) # Unindo os dataframes utilizando o .join()
display(tot)
# Out:
#   Jogador   Gols    Cartão        Time  Gols na Liga  Partidas
# 0    Pedro     3   Amarelo    Flamengo             4         4
# 1     João     2   Amarelo    Flamengo             5         5
# 2    Vitor     6  Vermelho  Fluminense             8         5
# 3     Ryan     1    Nenhum       Vasco             1         4

# %%
import matplotlib.pyplot as plt # Formatando DataFrame e mostrando na tela 

plt.figure(figsize=(10, 1))
plt.table(cellText=tot.values, colLabels=tot.columns, cellLoc='left', loc='center')
plt.axis('off')
plt.show()

# %%
# Criando gráfico a partir da coluna "Gols" utilizando o plot
tot['Gols'].plot(kind='line', grid=True, title="Gráfico", ylabel="Y", xlabel="X")
# Out:
# <Axes: title={'center': 'Gráfico'}, xlabel='X', ylabel='Y'>

# %% [markdown]
# # Retornando ao main_df

# %%
# Alterando os valores 'NAN' da tabela
main_df['tipo_de_gol'] = "Normal"
main_df['minuto_tab2'] = "45:00"
main_df['atleta_tab2'] =  "Player"

main_df
# Out:
#             rodata          clube    cartao                      atleta  \
# partida_id
# 4607             1    Figueirense   Amarelo      Paulo Roberto da Silva
# 4607             1    Figueirense   Amarelo               Thiago Heleno
# 4608             1  Internacional   Amarelo         Andrés D'Alessandro
# 4608             1        Vitoria   Amarelo  Marcelo Machado dos Santos
# 4608             1        Vitoria   Amarelo                      Mansur
# ...            ...            ...       ...                         ...
# 8405            38          Vasco   Amarelo                 Gabriel Pec
# 8405            38          Vasco   Amarelo                    Paulinho
# 8405            38          Vasco   Amarelo                  Gary Medel
# 8405            38     Bragantino   Amarelo               Eduardo Sasha
# 8405            38     Bragantino  Vermelho                  Léo Realpe
#
#             num_camisa     posicao minuto  partida_id  rodata_tab2  \
# partida_id
# ...

# %%
main_df.iloc[0:10, 0:6] # Procurando Valores nas colunas
# Out:
#             rodata          clube   cartao                      atleta  \
# partida_id
# 4607             1    Figueirense  Amarelo      Paulo Roberto da Silva
# 4607             1    Figueirense  Amarelo               Thiago Heleno
# 4608             1  Internacional  Amarelo         Andrés D'Alessandro
# 4608             1        Vitoria  Amarelo  Marcelo Machado dos Santos
# 4608             1        Vitoria  Amarelo                      Mansur
# 4608             1  Internacional  Amarelo    Juan Silveira dos Santos
# 4608             1        Vitoria  Amarelo       Vinícius Santos Silva
# 4609             1       Coritiba  Amarelo     Carlos Emiliano Pereira
# 4612             1          Bahia  Amarelo     Cristian Chagas Tarouco
# 4612             1          Bahia  Amarelo                     Rhayner
#
#             num_camisa     posicao
# partida_id
# 4607              28.0         NaN
# 4607               4.0    Zagueiro
# 4608              10.0  Meio-campo
# ...

# %%
main_df.sort_values(by=['num_camisa'], ascending=False) # Organizando valores a partir da coluna 'num_camisa'
# Out:
#             rodata        clube   cartao                           atleta  \
# partida_id
# 5687            33  Ponte Preta  Amarelo  Wendel Geraldo Maurício e Silva
# 7576            30    Fortaleza  Amarelo                 Robson Fernandes
# 7576            30    Fortaleza  Amarelo                           Felipe
# 7069            19    Fortaleza  Amarelo                       Yuri César
# 7576            30  Corinthians  Amarelo                     Róger Guedes
# ...            ...          ...      ...                              ...
# 4975            37        Goias  Amarelo                           Samuel
# 4977            38     Criciuma  Amarelo        Rafael Pereira dos Santos
# 4977            38     Criciuma  Amarelo          Gustavo Bonatto Barreto
# 4982            38  Botafogo-RJ  Amarelo           Maikon Alves de Aquino
# 4986            38        Goias  Amarelo                  Welinton Júnior
#
# ...

# %%
pd.crosstab(main_df['rodata'], main_df['clube']) # Criando DataFrame a partir de valores no DataFrame 'main_df'
# Out:
# clube   America-MG  Athletico-PR  Atletico-GO  Atletico-MG  Avai  Bahia  \
# rodata
# 1               11            19            8           24     6     12
# 2               13            25           11           16    14     14
# 3               11            30           11           17    15     17
# 4               11            23            8           28    13     19
# 5               16            26            9           26     9     25
# 6               15            25           11           22    13     18
# 7               15            25           10           25    16     14
# 8               11            21            6           25    14     19
# 9                6            28            6           23     7     16
# 10               8            28            7           26    12     21
# 11              12            18           10           25    19     21
# 12              14            27            7           17    15     15
# ...

# %% [markdown]
# # LIMPEZA DE DADOS

# %%
import os 
 
os.chdir(r'C:\Users\CAUÊ\Documents\Pandas\AnaliseDataset') 
os.getcwd()

path = pd.read_csv(r'C:\Users\CAUÊ\Documents\Pandas\AnaliseDataset\campeonato-brasileiro-gols.csv')

path.isna() # Revelando os valores 'NaN' do DataFrame
# Out:
#       partida_id  rodata  clube  atleta  minuto  tipo_de_gol
# 0          False   False  False   False   False        False
# 1          False   False  False   False   False        False
# 2          False   False  False   False   False         True
# 3          False   False  False   False   False         True
# 4          False   False  False   False   False         True
# ...          ...     ...    ...     ...     ...          ...
# 8927       False   False  False   False   False         True
# 8928       False   False  False   False   False         True
# 8929       False   False  False   False   False         True
# 8930       False   False  False   False   False         True
# 8931       False   False  False   False   False         True
#
# [8932 rows x 6 columns]

# %%
path.isna().sum() # Somando a quantidade de valores NaN do DataFrame
# Out:
# partida_id        0
# rodata            0
# clube             0
# atleta            0
# minuto            0
# tipo_de_gol    7843
# dtype: int64

# %%
path.isna().sum().sum()
# Out:
# 7843

# %%
path.head(21)
# Out:
#     partida_id  rodata          clube                            atleta  \
# 0         4607       1     Fluminense           Nirley da Silva Fonseca
# 1         4607       1     Fluminense                              Fred
# 2         4607       1     Fluminense                      Rafael Sóbis
# 3         4608       1  Internacional                  Charles Aránguiz
# 4         4612       1       Cruzeiro            Nílton Ferreira Júnior
# 5         4612       1       Cruzeiro                    Marcelo Moreno
# 6         4612       1          Bahia                  Anderson Talisca
# 7         4611       1      Sao Paulo  Antônio Carlos dos Santos Aguiar
# 8         4611       1      Sao Paulo        Douglas Pereira dos Santos
# 9         4611       1      Sao Paulo                      Luís Fabiano
# 10        4610       1   Athletico-PR            Dráusio Luis Salla Gil
# 11        4615       1         Santos                   Gabriel Barbosa
# ...

# %%
# Fazendo calculos com a coluna 'rodata'
mean = path['rodata'].mean()
median = path['rodata'].median()
mode = path['rodata'].mode()

display(mean, median, mode)
# Out:
# 19.563255709807432
# 20.0
# 0    31
# Name: rodata, dtype: int64

# %%
path['tipo_de_gol'] = path['tipo_de_gol'].fillna('Gol') # Alterando os valores onde o 'NaN' é existente
display(path)
# Out:
#       partida_id  rodata          clube                             atleta  \
# 0           4607       1     Fluminense            Nirley da Silva Fonseca
# 1           4607       1     Fluminense                               Fred
# 2           4607       1     Fluminense                       Rafael Sóbis
# 3           4608       1  Internacional                   Charles Aránguiz
# 4           4612       1       Cruzeiro             Nílton Ferreira Júnior
# ...          ...     ...            ...                                ...
# 8927        8403      38         Santos  Messias Rodrigues da Silva Júnior
# 8928        8404      38      Sao Paulo             Luciano da Rocha Neves
# 8929        8405      38          Vasco      Sergio Antonio De Luiz Junior
# 8930        8405      38     Bragantino                          Léo Ortiz
# 8931        8405      38          Vasco                           Paulinho
#
#      minuto tipo_de_gol
# 0        59  Gol Contra
# ...

# %%
path.head(50)
# Out:
#     partida_id  rodata          clube                               atleta  \
# 0         4607       1     Fluminense              Nirley da Silva Fonseca
# 1         4607       1     Fluminense                                 Fred
# 2         4607       1     Fluminense                         Rafael Sóbis
# 3         4608       1  Internacional                     Charles Aránguiz
# 4         4612       1       Cruzeiro               Nílton Ferreira Júnior
# 5         4612       1       Cruzeiro                       Marcelo Moreno
# 6         4612       1          Bahia                     Anderson Talisca
# 7         4611       1      Sao Paulo     Antônio Carlos dos Santos Aguiar
# 8         4611       1      Sao Paulo           Douglas Pereira dos Santos
# 9         4611       1      Sao Paulo                         Luís Fabiano
# 10        4610       1   Athletico-PR               Dráusio Luis Salla Gil
# ...

# %%
path.tipo_de_gol[6] = 'Gol de Falta' # Alterando Valores especificos na Tabela
csv = path.head(40)
display(csv)
# Out:
# C:\Users\CAUÊ\AppData\Local\Temp\ipykernel_832\3975219713.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   path.tipo_de_gol[6] = 'Gol de Falta' # Alterando Valores especificos na Tabela
# ...

# %%
path.head()
# Out:
#    partida_id  rodata          clube                   atleta minuto  \
# 0        4607       1     Fluminense  Nirley da Silva Fonseca     59
# 1        4607       1     Fluminense                     Fred     45
# 2        4607       1     Fluminense             Rafael Sóbis     31
# 3        4608       1  Internacional         Charles Aránguiz      6
# 4        4612       1       Cruzeiro   Nílton Ferreira Júnior     63
#
#   tipo_de_gol
# 0  Gol Contra
# 1     Penalty
# 2         Gol
# 3         Gol
# 4         Gol

# %%
df = pd.read_excel(r'C:\Users\CAUÊ\Documents\Pandas\AnaliseDataset\CustomerCal List.xlsx')
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df.drop(columns='Phone_Number')
# Out:
#     CustomerID First_Name    Last_Name                                Address  \
# 0         1001      Frodo      Baggins                  123 Shire Lane, Shire
# 1         1002       Abed        Nadir                    93 West Main Street
# 2         1003     Walter       /White                     298 Drugs Driveway
# 3         1004     Dwight      Schrute  980 Paper Avenue, Pennsylvania, 18503
# 4         1005        Jon         Snow                       123 Dragons Road
# 5         1006        Ron      Swanson                       768 City Parkway
# 6         1007       Jeff       Winger                      1209 South Street
# 7         1008   Sherlock       Holmes                          98 Clue Drive
# 8         1009    Gandalf          NaN                       123 Middle Earth
# 9         1010      Peter       Parker             25th Main Street, New York
# 10        1011    Samwise       Gamgee                  612 Shire Lane, Shire
# ...

# %%
df["Phone_Number"] = df["Phone_Number"].str.strip("123._/")
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins       -545-54
# 1         1002       Abed        Nadir      643/9775
# 2         1003     Walter       /White           NaN
# 3         1004     Dwight      Schrute     -543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson   04-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker       -545-54
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter           NaN
# 12        1013        Don       Draper     -543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_   04-762-2467
# 15        1016        Ron      Weasley       -545-54
# 16        1017   Michael         Scott      643/9775
# ...

# %%
df['Phone_Number'] = df['Phone_Number'].str.replace('[^a-zA-Z0-9]', '')
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins       -545-54
# 1         1002       Abed        Nadir      643/9775
# 2         1003     Walter       /White           NaN
# 3         1004     Dwight      Schrute     -543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson   04-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker       -545-54
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter           NaN
# 12        1013        Don       Draper     -543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_   04-762-2467
# 15        1016        Ron      Weasley       -545-54
# 16        1017   Michael         Scott      643/9775
# ...

# %%
#df['Phone_Number'].apply(lambda x: x[0:3] + '-' + x[3:6] + '-' + x[6:10])

df['Phone_Number'] = df['Phone_Number'].apply(lambda x: str(x))
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins       -545-54
# 1         1002       Abed        Nadir      643/9775
# 2         1003     Walter       /White           nan
# 3         1004     Dwight      Schrute     -543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson   04-762-2467
# 6         1007       Jeff       Winger           nan
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker       -545-54
# 10        1011    Samwise       Gamgee           nan
# 11        1012      Harry    ...Potter           nan
# 12        1013        Don       Draper     -543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_   04-762-2467
# 15        1016        Ron      Weasley       -545-54
# 16        1017   Michael         Scott      643/9775
# ...

# %%
df["Phone_Number"] = df["Phone_Number"].apply(lambda x: x[0:3] + '-' + x[3:6] + '-' + x[6:10])
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins   -54--5--5-4
# 1         1002       Abed        Nadir  643--/9-7-75
# 2         1003     Walter       /White            --
# 3         1004     Dwight      Schrute  -54--3--2-34
# 4         1005        Jon         Snow  876--|6-7-8|
# 5         1006        Ron      Swanson  04---76-2--2
# 6         1007       Jeff       Winger            --
# 7         1008   Sherlock       Holmes  876--|6-7-8|
# 8         1009    Gandalf          NaN            --
# 9         1010      Peter       Parker   -54--5--5-4
# 10        1011    Samwise       Gamgee            --
# 11        1012      Harry    ...Potter            --
# 12        1013        Don       Draper  -54--3--2-34
# 13        1014     Leslie        Knope  876--|6-7-8|
# 14        1015       Toby  Flenderson_  04---76-2--2
# 15        1016        Ron      Weasley   -54--5--5-4
# 16        1017   Michael         Scott  643--/9-7-75
# ...

# %%
df["Phone_Number"] = df["Phone_Number"].str.replace('nan--', '')
df["Phone_Number"] = df["Phone_Number"].str.replace('N/a--', '')
df["Phone_Number"] = df["Phone_Number"].str.replace('Na--', '')
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins   -54--5--5-4
# 1         1002       Abed        Nadir  643--/9-7-75
# 2         1003     Walter       /White            --
# 3         1004     Dwight      Schrute  -54--3--2-34
# 4         1005        Jon         Snow  876--|6-7-8|
# 5         1006        Ron      Swanson  04---76-2--2
# 6         1007       Jeff       Winger            --
# 7         1008   Sherlock       Holmes  876--|6-7-8|
# 8         1009    Gandalf          NaN            --
# 9         1010      Peter       Parker   -54--5--5-4
# 10        1011    Samwise       Gamgee            --
# 11        1012      Harry    ...Potter            --
# 12        1013        Don       Draper  -54--3--2-34
# 13        1014     Leslie        Knope  876--|6-7-8|
# 14        1015       Toby  Flenderson_  04---76-2--2
# 15        1016        Ron      Weasley   -54--5--5-4
# 16        1017   Michael         Scott  643--/9-7-75
# ...

# %%
df[["Street_Address", "State", "Zip_Code"]] = df["Address"].str.split(',', 2, expand=True)
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[133], line 1
# ----> 1 df[["Street_Address", "State", "Zip_Code"]] = df["Address"].str.split(',', 2, expand=True)
#       2 df
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\strings\accessor.py:137, in forbid_nonstring_types.<locals>._forbid_nonstring_types.<locals>.wrapper(self, *args, **kwargs)
#     132     msg = (
#     133         f"Cannot use .str.{func_name} with values of "
#     134         f"inferred dtype '{self._inferred_dtype}'."
#     135     )
#     136     raise TypeError(msg)
# --> 137 return func(self, *args, **kwargs)
#
# TypeError: StringMethods.split() takes from 1 to 2 positional arguments but 3 positional arguments (and 1 keyword-only argument) were given
