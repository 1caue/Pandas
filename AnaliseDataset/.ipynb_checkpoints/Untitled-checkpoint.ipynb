# %% [markdown]
# # Análise de dados utilizando o dataframe do campeonato brasileiro

# %%
import pandas as pd
from IPython.display import display

data = pd.read_csv(r'C:\Users\CAUÊ\Documents\Pandas\Analise de dados\campeonato-brasileiro-gols.csv')

data.head(10)
# Out:
#    partida_id  rodata          clube                            atleta minuto  \
# 0        4607       1     Fluminense           Nirley da Silva Fonseca     59
# 1        4607       1     Fluminense                              Fred     45
# 2        4607       1     Fluminense                      Rafael Sóbis     31
# 3        4608       1  Internacional                  Charles Aránguiz      6
# 4        4612       1       Cruzeiro            Nílton Ferreira Júnior     63
# 5        4612       1       Cruzeiro                    Marcelo Moreno     90
# 6        4612       1          Bahia                  Anderson Talisca     80
# 7        4611       1      Sao Paulo  Antônio Carlos dos Santos Aguiar     13
# 8        4611       1      Sao Paulo        Douglas Pereira dos Santos     22
# 9        4611       1      Sao Paulo                      Luís Fabiano     56
#
#   tipo_de_gol
# 0  Gol Contra
# 1     Penalty
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# ...

# %%
data.query('clube == "Bahia" and atleta == "Anderson Talisca"').head()
# Out:
#      partida_id  rodata  clube            atleta minuto tipo_de_gol
# 6          4612       1  Bahia  Anderson Talisca     80     Penalty
# 107        4658       6  Bahia  Anderson Talisca   90+2         NaN
