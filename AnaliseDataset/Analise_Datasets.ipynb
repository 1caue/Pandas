# %% [markdown]
# # Analisando a Tabela Fipe de 2022

# %%
import pandas as pd
fipe = pd.read_csv(r'C:\Users\CAUÊ\Documents\Pandas\fipe_2022.csv')
fipe.shape
# Out:
# (290275, 12)

# %%
fipe.head(35)
# Out:
#     year_of_reference month_of_reference fipe_code authentication   brand  \
# 0                2022            January  038001-6     vwmrywl5qs   Acura
# 1                2022            January  038001-6     t9mt723qhz   Acura
# 2                2022            January  038001-6     tr5wv4z21g   Acura
# 3                2022            January  038001-6     s2xxsjz3mt   Acura
# 4                2022            January  038001-6     rtm9gj7zk8   Acura
# 5                2022            January  038002-4     nlf2w6k7vd   Acura
# 6                2022            January  038002-4     mcyp7ypwtc   Acura
# 7                2022            January  038002-4     lxckds9y6h   Acura
# 8                2022            January  038002-4     k1fntq7ycs   Acura
# 9                2022            January  038002-4     j1b3jg70bz   Acura
# 10               2022            January  038002-4     h105mb94fn   Acura
# 11               2022            January  038002-4     hsmx1mgjty   Acura
# ...

# %%
finalfil = fipe[(fipe['brand'] == "BMW") & (fipe['gear'] == "manual") & (fipe['year_of_reference'] == 2022)]
finalfil
# Out:
#         year_of_reference month_of_reference fipe_code authentication brand  \
# 1235                 2022            January  009001-8    l4lthc584vp   BMW
# 1236                 2022            January  009001-8    k5dwjhmq7hp   BMW
# 1237                 2022            January  009001-8    kx2b07ydfhp   BMW
# 1238                 2022            January  009001-8    kppqq3wht0p   BMW
# 1239                 2022            January  009001-8    j5nvzr7cyhp   BMW
# ...                   ...                ...       ...            ...   ...
# 268010               2022           December  009290-8  tcndh6nf87dmn   BMW
# 268011               2022           December  009291-6    74q7z3pjggp   BMW
# 268012               2022           December  009291-6  5txc1kq8lddmn   BMW
# 268019               2022           December  009299-1    wtdlk6fwrfp   BMW
# 268020               2022           December  009299-1  vy1pq6h9j1dqw   BMW
#
# ...

# %%
Acura = fipe[(fipe['brand'] == "Agrale") & (fipe['year_model'] == 2022)]
Acura
# Out:
#         year_of_reference month_of_reference fipe_code authentication   brand  \
# 57                   2022            January  060007-5  qqy3d7j7tsdm9  Agrale
# 74                   2022            January  060008-3  q8kxsqjmd0dm9  Agrale
# 90                   2022            January  060009-1  t9b5hbhqdtdm9  Agrale
# 93                   2022            January  060010-5  tslp0ph76bdm9  Agrale
# 24088                2022           February  060007-5  qt1g03dh85dm9  Agrale
# 24105                2022           February  060008-3  rcsdql5ryqdm9  Agrale
# 24121                2022           February  060009-1  vj9m0vjv6rdm9  Agrale
# 24124                2022           February  060010-5  txfkhy5vv4dm9  Agrale
# 48182                2022              March  060007-5  qx4l9g9n0ddm9  Agrale
# 48199                2022              March  060008-3  rg0pfypzgsdm9  Agrale
# 48215                2022              March  060009-1  vpbbxrz6tndm9  Agrale
# ...
