# %% [markdown]
# # Análise de DataSet (Sars Cov-19)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from urllib.request import urlretrieve

# %%
df = pd.read_csv(r'C:\Users\CAUÊ\Documents\Pandas\Numpy\time_series_covid19_confirmed_global.csv')
df
# Out:
#     Province/State        Country/Region        Lat        Long  1/22/20  \
# 0              NaN           Afghanistan  33.939110   67.709953        0
# 1              NaN               Albania  41.153300   20.168300        0
# 2              NaN               Algeria  28.033900    1.659600        0
# 3              NaN               Andorra  42.506300    1.521800        0
# 4              NaN                Angola -11.202700   17.873900        0
# ..             ...                   ...        ...         ...      ...
# 284            NaN    West Bank and Gaza  31.952200   35.233200        0
# 285            NaN  Winter Olympics 2022  39.904200  116.407400        0
# 286            NaN                 Yemen  15.552727   48.516388        0
# 287            NaN                Zambia -13.133897   27.849332        0
# 288            NaN              Zimbabwe -19.015438   29.154857        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  2/28/23  3/1/23  \
# ...

# %%
df.head()
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  2/28/23  3/1/23  3/2/23  3/3/23  \
# 0        0        0        0        0  ...   209322  209340  209358  209362
# 1        0        0        0        0  ...   334391  334408  334408  334427
# 2        0        0        0        0  ...   271441  271448  271463  271469
# 3        0        0        0        0  ...    47866   47875   47875   47875
# 4        0        0        0        0  ...   105255  105277  105277  105277
#
#    3/4/23  3/5/23  3/6/23  3/7/23  3/8/23  3/9/23
# ...

# %%
df.drop(['Lat', 'Long'], axis=1, inplace=True)

# %%
country = df.groupby('Country/Region').sum()
country
# Out:
#                      Province/State  1/22/20  1/23/20  1/24/20  1/25/20  \
# Country/Region
# Afghanistan                       0        0        0        0        0
# Albania                           0        0        0        0        0
# Algeria                           0        0        0        0        0
# Andorra                           0        0        0        0        0
# Angola                            0        0        0        0        0
# ...                             ...      ...      ...      ...      ...
# West Bank and Gaza                0        0        0        0        0
# Winter Olympics 2022              0        0        0        0        0
# Yemen                             0        0        0        0        0
# Zambia                            0        0        0        0        0
# Zimbabwe                          0        0        0        0        0
#
#                       1/26/20  1/27/20  1/28/20  1/29/20  1/30/20  ...  \
# ...

# %%
date = country.loc['Brazil'].index
cases = country.loc['Brazil'].values

# %%
date
# Out:
# Index(['Province/State', '1/22/20', '1/23/20', '1/24/20', '1/25/20', '1/26/20',
#        '1/27/20', '1/28/20', '1/29/20', '1/30/20',
#        ...
#        '2/28/23', '3/1/23', '3/2/23', '3/3/23', '3/4/23', '3/5/23', '3/6/23',
#        '3/7/23', '3/8/23', '3/9/23'],
#       dtype='object', length=1144)

# %%
cases
# Out:
# array([0, 0, 0, ..., 37076053, 37076053, 37076053], dtype=object)

# %%
df.shape
# Out:
# (289, 1145)

# %%
plt.figure(figsize=(14,8))
plt.bar(date, cases)
# Out:
# <BarContainer object of 1144 artists>

# %%
s_brazil = country.loc['Brazil']

# %%
s_brazil
# Out:
# Province/State           0
# 1/22/20                  0
# 1/23/20                  0
# 1/24/20                  0
# 1/25/20                  0
#                     ...
# 3/5/23            37081209
# 3/6/23            37076053
# 3/7/23            37076053
# 3/8/23            37076053
# 3/9/23            37076053
# Name: Brazil, Length: 1144, dtype: object

# %%
s_brazil = s_brazil[s_brazil > 0]

# %%
s_brazil
# Out:
# 2/26/20           1
# 2/27/20           1
# 2/28/20           1
# 2/29/20           2
# 3/1/20            2
#              ...
# 3/5/23     37081209
# 3/6/23     37076053
# 3/7/23     37076053
# 3/8/23     37076053
# 3/9/23     37076053
# Name: Brazil, Length: 1108, dtype: object

# %%
s_brazil.index
# Out:
# Index(['2/26/20', '2/27/20', '2/28/20', '2/29/20', '3/1/20', '3/2/20',
#        '3/3/20', '3/4/20', '3/5/20', '3/6/20',
#        ...
#        '2/28/23', '3/1/23', '3/2/23', '3/3/23', '3/4/23', '3/5/23', '3/6/23',
#        '3/7/23', '3/8/23', '3/9/23'],
#       dtype='object', length=1108)

# %%
s_brazil.values
# Out:
# array([1, 1, 1, ..., 37076053, 37076053, 37076053], dtype=object)

# %%
tam = len(s_brazil)

plt.figure(figsize=(14,8))
plt.xticks(rotation=89)
plt.bar(date, cases)
plt.title('Total de casos confirmados de COVID-19 no Brasil')
# Out:
# Text(0.5, 1.0, 'Total de casos confirmados de COVID-19 no Brasil')
